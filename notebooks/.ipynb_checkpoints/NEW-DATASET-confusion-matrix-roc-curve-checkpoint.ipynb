# %%
# AUTHOR: ANTTI KIVIAHO
# EMAIL: antti.kiviaho@tuni.fi
#
#
#
# A script for plotting confusion matrices and ROC curves of ready-made prediction results

# %%
import os
import sys
from logzero import logger
from matplotlib import pyplot as plt
from itertools import cycle
from scipy import stats

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from enum import IntEnum

from keras.models import load_model

from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
class toIntEnum(IntEnum):
    wt = 0
    MED12 = 1
    HMGA2 = 2
    YEATS4 = 3

# %%
tfrecord_contents = pd.read_csv('/lustre/scratch/kiviaho/myoma/myoma-new/new_dataset_tfrecords_contents.csv')

# %%
model_name = 'two-labels-InceptionV3_40_epochs_5_percent_21118730_at_2022-03-31_16:08:12_598px.h5_new_dataset_prediction_results.csv'
results = pd.read_csv('/lustre/scratch/kiviaho/myoma/myoma-new/'+model_name)
tfrecord_contents = tfrecord_contents[:len(results)]
#gt_tile = results['Label']
results = results.rename(columns={'0': 0, '1': 1})

pred = np.array(results[[0,1]],dtype=np.float32)

# %%
results= pd.concat([tfrecord_contents.reset_index(drop=True), results], axis=1)
results['gt'] = results['Label']
results['Label'] = 1

# %%
results
# Out:
#          Unnamed: 0    Sample  \
# 0                 0  My6193m1
# 1                 1  My6113m5
# 2                 2  My6193m1
# 3                 3  My6095m4
# 4                 4  My6148m1
# ...             ...       ...
# 1933571     1933571  My6223m1
# 1933572     1933572  My6119m4
# 1933573     1933573  My6372m1
# 1933574     1933574  My6138m2
# 1933575     1933575  My6140m4
#
#                                                       Path  Label         0  \
# 0        /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.269339
# 1        /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.000095
# 2        /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.006630
# 3        /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.000016
# 4        /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.029042
# ...                                                    ...    ...       ...
# 1933571  /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.000001
# 1933572  /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.016309
# 1933573  /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.208735
# 1933574  /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.000343
# 1933575  /lustre/scratch/kiviaho/myoma/myoma-new/new_ti...      1  0.000058
#
#                 1  gt
# 0        0.729567   2
# 1        0.999904   1
# 2        0.993270   2
# 3        0.999984   1
# 4        0.970860   1
# ...           ...  ..
# 1933571  0.999999   2
# 1933572  0.983510   1
# 1933573  0.789777   2
# 1933574  0.999654   1
# 1933575  0.999943   1
#
# [1933576 rows x 7 columns]

# %%
#gt_tile = np.repeat(1,len(tfrecord_contents))
gt_tile = np.asarray(results['Label'])

# %%
# get predictions into single column
# for confusion matrix
predictions = np.argmax(pred, axis=1)

# probability for ROC
probs = results.loc[:,[0,1]]

target_names = ['wt','mut']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_tile, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_tile, predictions,
                            target_names=target_names)
logger.info(cr)

## Add ROC and AUC
#auc_cm = roc_auc_score(gt_tile, probs[1])
#logger.info(auc_cm)

fpr, tpr, thresholds = roc_curve(gt_tile, probs[1])
# model_auc = auc(fpr, tpr)

ax1 = plt.axes()
akws = {"ha": 'left',"va": 'center'}
sns.set(font_scale=1.3)
sns.heatmap([[1,0],[0,1]], annot=cm, ax = ax1, fmt='g', annot_kws=akws,linewidths=2, cbar =False,cmap=('RdYlGn'), linecolor='black')
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Tile Level Confusion Matrix – New Slides')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)
ax1.figure.set_size_inches((10,8))
binary_conf_matrix = ax1
# Out:
# [D 220510 15:22:37 4096630577:9] Confusion Matrix
# [I 220510 15:22:37 4096630577:11] [[      0       0]
#      [ 137612 1795964]]
# [D 220510 15:22:37 4096630577:13] Classification Report
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 220510 15:22:40 4096630577:16]               precision    recall  f1-score   support
#
#               wt       0.00      0.00      0.00         0
#              mut       1.00      0.93      0.96   1933576
#
#         accuracy                           0.93   1933576
#        macro avg       0.50      0.46      0.48   1933576
#     weighted avg       1.00      0.93      0.96   1933576
#
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:992: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   UndefinedMetricWarning,

# %%
sample_level = results.loc[:,['Sample','Label','gt',0,1]].groupby(['Sample']).mean()
gt_sample = sample_level.loc[:,['Label']]

# get predictions into single column
# for confusion matrix
predictions = sample_level.loc[:,[0,1]].idxmax(axis= 1)

# probability for ROC
probs = sample_level.loc[:,[0,1]]

target_names = ['wt','mut']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_sample, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_sample, predictions,
                            target_names=target_names,digits=3)
logger.info(cr)

ax1 = plt.axes()
akws = {"ha": 'left',"va": 'center'}
#sns.set(font_scale=1.3)
sns.heatmap([[1,0],[0,1]], annot=cm, ax = ax1, fmt='g', annot_kws=akws,linewidths=2, cbar =False,cmap=('RdYlGn'), linecolor='black')
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Sample Level Confusion Matrix – New Slides')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)
ax1.figure.set_size_inches((10,8))
binary_conf_matrix = ax1
# Out:
# [D 220510 15:22:47 1309626456:12] Confusion Matrix
# [I 220510 15:22:47 1309626456:14] [[ 0  0]
#      [ 1 49]]
# [D 220510 15:22:47 1309626456:16] Classification Report
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 220510 15:22:47 1309626456:19]               precision    recall  f1-score   support
#
#               wt      0.000     0.000     0.000         0
#              mut      1.000     0.980     0.990        50
#
#         accuracy                          0.980        50
#        macro avg      0.500     0.490     0.495        50
#     weighted avg      1.000     0.980     0.990        50

# %%
sample_level
# Out:
#            Label  gt         0         1
# Sample
# My6095m4       1   1  0.037545  0.962394
# My6098m2       1   1  0.037343  0.962621
# My6101m1       1   1  0.036251  0.963654
# My6103m1       1   1  0.026446  0.973465
# My6113m1       1   1  0.054081  0.945896
# My6113m2       1   1  0.099820  0.900238
# My6113m3       1   1  0.014483  0.985491
# My6113m4       1   1  0.063681  0.936293
# My6113m5       1   1  0.086991  0.912921
# My6117m3       1   1  0.033094  0.966865
# My6119m1       1   1  0.032662  0.967345
# My6119m3       1   1  0.024023  0.975982
# My6119m4       1   1  0.037919  0.962032
# My6121m2       1   1  0.036805  0.963100
# My6121m4       1   1  0.116806  0.883179
# My6122m2       1   1  0.069884  0.930032
# My6122m9       1   1  0.095317  0.904627
# My6123m3       1   1  0.124924  0.874934
# My6127m6       1   1  0.012494  0.987513
# My6135m1       1   1  0.127834  0.872050
# My6137m6       1   1  0.070733  0.929211
# My6138m2       1   1  0.064805  0.935060
# My6139m2       1   1  0.349892  0.649545
# My6139m5       1   1  0.055367  0.944579
# My6140m4       1   1  0.033974  0.965928
# My6140m7       1   1  0.014171  0.985787
# My6140m9       1   1  0.026860  0.973172
# My6141m3       1   1  0.122040  0.877777
# My6141m9       1   1  0.140804  0.859038
# My6143m2       1   1  0.221307  0.778786
# My6144m3       1   1  0.061752  0.938157
# My6145m11      1   1  0.031648  0.968291
# My6145m12      1   1  0.044080  0.955826
# My6145m5       1   1  0.003944  0.996048
# My6147m1       1   1  0.091856  0.907864
# My6148m1       1   1  0.063850  0.936111
# My6148m4       1   1  0.147301  0.852534
# My6152m3       1   1  0.193113  0.806648
# My6173m1       1   2  0.069552  0.930307
# My6193m1       1   2  0.138814  0.860983
# My6209m1       1   2  0.801443  0.198345
# My6218m1       1   2  0.042462  0.957420
# My6223m1       1   2  0.099689  0.900230
# My6236m9       1   3  0.046905  0.953063
# My6251m1       1   2  0.148817  0.850982
# My6269m2       1   2  0.105339  0.894353
# My6270m1       1   2  0.062844  0.937094
# My6325m7       1   3  0.448727  0.550340
# My6367m3       1   1  0.197087  0.802513
# My6372m1       1   2  0.128764  0.871006

# %%
med12_wt_pred = sample_level.loc[sample_level['gt'] == 1][0]
hmga2_wt_pred = sample_level.loc[sample_level['gt'] == 2][0]
yeats4_wt_pred = sample_level.loc[sample_level['gt'] == 3][0]

# %%
stats.ttest_ind(med12_wt_pred,hmga2_wt_pred)
# Out:
# Ttest_indResult(statistic=-2.2568104993323104, pvalue=0.02881390045409724)

# %%
stats.ttest_ind(med12_wt_pred,yeats4_wt_pred)
# Out:
# Ttest_indResult(statistic=-2.808852210689399, pvalue=0.007729620658845925)

# %%
stats.ttest_ind(yeats4_wt_pred,hmga2_wt_pred)
# Out:
# Ttest_indResult(statistic=0.3708712460742545, pvalue=0.7193125863977433)

# %%
sample_level.to_csv("sample_level_predictions_binary_class.csv",sep=";",decimal=",")

# %%
model_name = 'InceptionV3_40_epochs_5_percent_21120094_at_2022-04-01_10:56:09_598px.h5_multiclass_prediction_results.csv'
results = pd.read_csv('/lustre/scratch/kiviaho/myoma/myoma-new/'+model_name)
results = results[:631320]
gt_tile = results['Label']
results = results.rename(columns={'0': 0, '1': 1,'2':2,'3':3,'4':4})


pred = np.array(results[[0,1,2,3,4]],dtype=np.float32)

# %%
# get predictions into single column
# for confusion matrix
probs = results.loc[:,[0,1,2,3,4]]

predictions = probs.idxmax(axis=1)


target_names = ['wild', 'SNV44','DELINS','SNV36','SNV43']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_tile, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_tile, predictions,
                            target_names=target_names,digits=3)
logger.info(cr)

## Add ROC and AUC
#auc = roc_auc_score(gt_tile, probs, multi_class='ovr')
#logger.info(auc_cm)

filename = str(model_name).replace('results/', '')
filename = filename.replace('_598px.h5', '')

ax1 = plt.subplot(111)
akws = {"ha": 'left',"va": 'center'}
sns.heatmap(cm, annot=True, ax = ax1, fmt='g', annot_kws=akws)
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Confusion Matrix')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)


plt.savefig(filename + '.png', dpi=300)
# Out:
# [D 220427 09:41:49 3410938536:9] Confusion Matrix
# [I 220427 09:41:49 3410938536:11] [[ 89006  11062  36760   7828   5085]
#      [ 57297 104253 122022  44031  21378]
#      [ 13676  21712  17865  11792   4212]
#      [  5953  19336  28684   8679    689]
#      [     0      0      0      0      0]]
# [D 220427 09:41:49 3410938536:13] Classification Report
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 220427 09:41:50 3410938536:16]               precision    recall  f1-score   support
#
#             wild      0.536     0.594     0.564    149741
#            SNV44      0.667     0.299     0.413    348981
#           DELINS      0.087     0.258     0.130     69257
#            SNV36      0.120     0.137     0.128     63341
#            SNV43      0.000     0.000     0.000         0
#
#         accuracy                          0.348    631320
#        macro avg      0.282     0.258     0.247    631320
#     weighted avg      0.517     0.348     0.389    631320

# %%
#concat_results = pd.concat([tfrec_info.reset_index(drop=True), results], axis=1)

sample_level = results.loc[:,['Sample','Label',0,1,2,3,4]].groupby(['Sample']).mean()
gt_sample = sample_level.loc[:,['Label']]

# %%
# Construct confusion matrix

probs = sample_level.loc[:,[0,1,2,3,4]]

predictions = probs.idxmax(axis=1)


target_names = ['wild', 'SNV44','DELINS','SNV36','SNV43']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_sample, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_sample, predictions,
                            target_names=target_names,digits=3)
logger.info(cr)


filename = str(model_name).replace('results/', '')
filename = filename.replace('_598px.h5', '')

ax1 = plt.axes()
akws = {"ha": 'left',"va": 'center'}
sns.heatmap(np.diag(np.ones(5)), annot=cm, ax = ax1, fmt='g', annot_kws=akws,linewidths=2, cbar =False,cmap=('RdYlGn'), linecolor='black')
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Confusion Matrix')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)
ax1.figure.set_size_inches((10,7))

plt.savefig('multiclass_classification_confusion_matrix.png', dpi=300)
# Out:
# [D 220427 09:41:51 2443121780:9] Confusion Matrix
# [I 220427 09:41:51 2443121780:11] [[7 0 1 0 0]
#      [1 8 9 2 1]
#      [1 2 2 0 0]
#      [0 1 3 0 0]
#      [0 0 0 0 0]]
# [D 220427 09:41:51 2443121780:13] Classification Report
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 220427 09:41:51 2443121780:16]               precision    recall  f1-score   support
#
#             wild      0.778     0.875     0.824         8
#            SNV44      0.727     0.381     0.500        21
#           DELINS      0.133     0.400     0.200         5
#            SNV36      0.000     0.000     0.000         4
#            SNV43      0.000     0.000     0.000         0
#
#         accuracy                          0.447        38
#        macro avg      0.328     0.331     0.305        38
#     weighted avg      0.583     0.447     0.476        38

# %%
sample_level.to_csv("sample_level_predictions_multiclass.csv",sep=";",decimal=",")

# %%
# ADD ONE INSTANCE OF CLASS 4
# OTHERWISE ROC/AUC CALCULATIONS FAIL
# PREPROCESS THE ARRATS TO MATCH 

n_classes = 5
target_names = ['wild type', 'SNV44','DELINS','SNV36','SNV43']
lw = 1

#gt_tile_mod = np.append(gt_tile,4)
#results_mod = results.append(pd.DataFrame({'foo':['foo','foo',4,1,0,0,0,0]},index=['Sample','Path','Label',0,1,2,3,4,]).transpose())

results_mod = results
gt_tile_mod = np.squeeze(np.array(gt_tile,dtype=np.int16))

gt_tile_mod = np.array(tf.one_hot(gt_tile_mod,n_classes),dtype=np.int16)
results_mod = np.array(results_mod.loc[:,[0,1,2,3,4]],dtype=np.float32)
# Out:
# 2022-04-27 09:41:52.196904: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/opt/cuda-11.2/lib64
# 2022-04-27 09:41:52.196976: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-27 09:41:52.197024: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (narvi-shell.cc.tut.fi): /proc/driver/nvidia/version does not exist
# 2022-04-27 09:41:52.198065: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gt_tile_mod[:, i], results_mod[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:1001: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning,

# %%
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(gt_tile_mod.ravel(), results_mod.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=lw,
        label= target_names[i] + " (area = %0.2f)" % roc_auc[i],
    )
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="Average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)


colors = cycle(["aqua", "darkorange", "cornflowerblue",'violet'])
for i, color in zip(range(n_classes-1), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label= target_names[i] + " (area = %0.2f)" % roc_auc[i],
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Tile Level Receiver Operating Charasteristic")
plt.legend(loc="lower right")
plt.tight_layout()
plt.savefig(filename + '_ROC_tile_level.png', dpi=300)

# %%
n_classes = 5
target_names = ['wild type', 'SNV44','DELINS','SNV36','SNV43']
lw = 1

# NO NEED TO ADD A PSEUDO COUNT SINCE THIS IS MICRO AVERAGING
#gt_sample_mod = np.append(gt_sample,4)
#results_mod = sample_level.append(pd.DataFrame({'foo':['foo','foo',4,0,0,0,0,1]},index=['Sample','Path','Label',0,1,2,3,4,]).transpose())
results_mod = sample_level
gt_sample_mod = np.squeeze(np.array(gt_sample,dtype=np.int16))

gt_sample_mod = np.array(tf.one_hot(gt_sample_mod,n_classes),dtype=np.int16)
results_mod = np.array(results_mod.loc[:,[0,1,2,3,4]],dtype=np.float32)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gt_sample_mod[:, i], results_mod[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:1001: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning,

# %%
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(gt_sample_mod.ravel(), results_mod.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="Average ROC curve (area = {0:0.3f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)


colors = cycle(["aqua", "darkorange", "cornflowerblue",'violet'])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label= target_names[i] + " (area = %0.3f)" % roc_auc[i],
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Sample Level Receiver Operating Charasteristic")
plt.legend(loc="lower right")
plt.tight_layout()
plt.savefig(filename + '_ROC_sample_level.png', dpi=300)

# %%
roc_auc['micro']
# Out:
# 0.8085180055401663
