# %%
import os
import sys
import glob
import pickle
import argparse
import time

import numpy as np
import pandas as pd
import seaborn as sns

from functools import partial
from logzero import logger
from matplotlib import pyplot as plt
from enum import IntEnum

os.environ['HDF5_USE_FILE_LOCKING']='FALSE'

import tensorflow as  tf
from keras import backend as K
from keras.models import load_model

from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from keras.preprocessing import image

BATCH_SIZE = 8 
IMAGE_SIZE = (598,598)
N_TARGETS = 2 # CHANGE IN ORDER TO USE MULTILABEL

# %%
# Sample labeling scheme for string to enum
# Import in all scripts necessary
class toIntEnum(IntEnum):
    wt = 0
    SNV44 = 1
    DELINS = 2
    SNV36 = 3
    SNV43 = 4

# %%
### DEFINITIONS ###
# This is for predicting
def parse_tfrecord_fn(example):
    feature_description = {
      'img': tf.io.FixedLenFeature([], tf.string),
      'sample': tf.io.FixedLenFeature([], tf.string),
      'int_label': tf.io.FixedLenFeature([], tf.int64),
      'path': tf.io.FixedLenFeature([], tf.string),
      'label':  tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, feature_description)
    image = tf.io.decode_jpeg(example['img'], channels=3)/255
    
    # Flip along the horizontal axis and rotate randomly (no biases)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.rot90(image,k=int(np.random.choice((1,2,3,4),1)))
    example['img'] = image
    if N_TARGETS ==2:
        example['int_label'] = tf.cond(tf.math.greater(example['int_label'], 0), lambda: 1, lambda: 0)
    example['int_label'] = tf.one_hot(example['int_label'],N_TARGETS)
    return example


def get_dataset(filenames):
    dataset = load_dataset(filenames)
    dataset = dataset.prefetch(buffer_size=50)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder = True)
    dataset = dataset.map(reshape_data)
    return dataset


def load_dataset(filenames):
    dataset = tf.data.TFRecordDataset(
        filenames
        )  # automatically interleaves reads from multiple files
    dataset = dataset.map(
        partial(parse_tfrecord_fn), num_parallel_calls=50
    )
    # returns a dataset of (image, label) pairs
    return dataset

def reshape_data(dataset):
    image = tf.reshape(dataset['img'],(BATCH_SIZE,*IMAGE_SIZE,3))
    label = tf.reshape(dataset['int_label'],(BATCH_SIZE,N_TARGETS))
    return image,label

def rename_columns(df):
    cols = []
    for col in df.columns:
        cols.append(toIntEnum(col).name)
    df = df.set_axis(cols,axis=1)
    return df

# %%
### DATA IMPORT ###
n_files_use = 1

BATCH_SIZE = 8

path = '/lustre/nvme/kiviaho/'
sample_sheet = pd.read_csv('/lustre/nvme/kiviaho/tfrecords/test_set_with_tile_path_tfrecord-ENCODING-V3.tsv', sep = '\t')
files = list(dict.fromkeys(sample_sheet['TFRecords'])) # This preserves the order, unlike set !!
files = [path + f  for f in files]
TEST_BATCHES = np.floor(len(sample_sheet)/BATCH_SIZE).astype(int)

# %%
test_dataset = get_dataset(files[:n_files_use])

# %%
image_batch, label_batch = next(iter(test_dataset))

plt.figure(figsize=(10, 10))
for n in range(8):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(image_batch[n]) 
    plt.title(
        label_batch[n].numpy()
        #sample_batch[n].numpy().decode()
        #path_batch[n].numpy().decode()
             )
    plt.axis("off")
# Out:
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/matplotlib/text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
tfrec_info = pd.read_csv('/lustre/scratch/kiviaho/myoma/myoma-new/test-set-tfrecord-info-correct-order.csv',
                               index_col=0)
tfrec_info = tfrec_info[:n_files_use*800]

# %%
gt_tile = tfrec_info['Label']

for i in range(len(gt_tile)):
    if gt_tile[i] != 0:
        gt_tile[i] = 1
# Out:
# /home/ak431480/.conda/envs/myoma-new-env/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# Testing previously trained models on the data
model_name = 'two-labels-InceptionV3_40_epochs_5_percent_21118730_at_2022-03-31_16:08:12_598px.h5'
model = load_model('/lustre/scratch/kiviaho/myoma/myoma-new/results/'+ model_name)

start = time.time()
pred = model.predict(test_dataset)
time.time()-start

gt_tile = gt_tile[:len(pred)]
# Out:
# 88.12590599060059

# %%
results = pd.DataFrame(pred)
results_for_saving = pd.concat([tfrec_info,results],axis=1) 

results['ground_truth'] = gt_tile.idxmax(axis=1)
name = str(model_name) + '.prediction_results.csv'
results_for_saving.to_csv(name, index=False)

# %%
### LOADING THE PREDICTIONS AND PLOTTING ####

# %%
results = pd.read_csv('/lustre/scratch/kiviaho/myoma/myoma-new/two-labels-InceptionV3_40_epochs_5_percent_21118730_at_2022-03-31_16:08:12_598px.h5.prediction_results.csv')
results = results[:631320]
gt_tile = results['Label']

# %%
pred = np.array(results[['0','1']],dtype=np.float32)

# %%
# get predictions into single column
# for confusion matrix
predictions = np.argmax(pred, axis=1)

# probability for ROC
probs = results.loc[:,['0','1']]

#target_names = ['wild', 'SNV44','DELINS','SNV36','SNV43']
target_names = ['wt','mut']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_tile, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_tile, predictions,
                            target_names=target_names)
logger.info(cr)

## Add ROC and AUC
auc = roc_auc_score(gt_tile, probs['1'])#, multi_class='ovr')
logger.info(auc)

fpr, tpr, thresholds = roc_curve(gt_tile, probs['1'])
# model_auc = auc(fpr, tpr)

filename = str(model_name).replace('results/', '')
filename = filename.replace('_598px.h5', '')

fig, (ax1, ax2) = plt.subplots(2,1)
akws = {"ha": 'left',"va": 'center'}
sns.heatmap(cm, annot=True, ax = ax1, fmt='g', annot_kws=akws)
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Confusion Matrix')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)

ax2.plot([0, 1], [0, 1], 'k--')
ax2.plot(fpr, tpr, label='Prediction (area = {:.3f})'.format(auc))
ax2.set_xlabel('False positive rate')
ax2.set_ylabel('True positive rate')
ax2.set_title('ROC curve')
ax2.legend(loc='best')
fig.suptitle(filename, fontsize=12)
fig.set_size_inches(8, 12)
logger.info("Saving classification report plots")
fig.savefig(filename + '.pdf', dpi=300)
# Out:
# [D 220420 14:13:01 3270394998:10] Confusion Matrix
# [I 220420 14:13:01 3270394998:12] [[112582  37159]
#      [149296 332283]]
# [D 220420 14:13:01 3270394998:14] Classification Report
# [I 220420 14:13:02 3270394998:17]               precision    recall  f1-score   support
#
#               wt       0.43      0.75      0.55    149741
#              mut       0.90      0.69      0.78    481579
#
#         accuracy                           0.70    631320
#        macro avg       0.66      0.72      0.66    631320
#     weighted avg       0.79      0.70      0.73    631320
#
# [I 220420 14:13:02 3270394998:21] 0.7920252002587889
# [I 220420 14:13:02 3270394998:47] Saving classification report plots

# %%
#concat_results = pd.concat([tfrec_info.reset_index(drop=True), results], axis=1)
sample_level = results.loc[:,['Sample','Label','0','1']].groupby(['Sample']).mean()
gt_sample = sample_level.loc[:,['Label']]
sample_level = sample_level.rename(columns={'0': 0, '1': 1})

# %%
# get predictions into single column
# for confusion matrix
predictions = sample_level.loc[:,[0,1]].idxmax(axis= 1)

# probability for ROC
probs = sample_level.loc[:,[0,1]]

target_names = ['wt','mut']
logger.debug("Confusion Matrix")
cm = confusion_matrix(gt_sample, predictions)
logger.info(cm)

logger.debug("Classification Report")
cr = classification_report(gt_sample, predictions,
                            target_names=target_names)
logger.info(cr)

## Add ROC and AUC
auc = roc_auc_score(gt_sample, probs[1])#, multi_class='ovr')
logger.info(auc)

fpr, tpr, thresholds = roc_curve(gt_sample, probs[1])
# model_auc = auc(fpr, tpr)

filename = str(model_name).replace('results/', '')
filename = filename.replace('_598px.h5', '')

fig, (ax1, ax2) = plt.subplots(2,1)
akws = {"ha": 'left',"va": 'center'}
sns.heatmap(cm, annot=True, ax = ax1, fmt='g', annot_kws=akws)
# labels, title and ticks
ax1.set_xlabel('Predicted labels')
ax1.set_ylabel('True labels')
ax1.set_title('Confusion Matrix')
ax1.xaxis.set_ticklabels(target_names)
ax1.yaxis.set_ticklabels(target_names)

ax2.plot([0, 1], [0, 1], 'k--')
ax2.plot(fpr, tpr, label='Prediction (area = {:.3f})'.format(auc))
ax2.set_xlabel('False positive rate')
ax2.set_ylabel('True positive rate')
ax2.set_title('ROC curve')
ax2.legend(loc='best')
fig.suptitle(filename, fontsize=12)
fig.set_size_inches(8, 12)
logger.info("Saving classification report plots")
fig.savefig(filename + '.pdf', dpi=300)
# Out:
# [D 220420 14:20:44 3736149128:9] Confusion Matrix
# [I 220420 14:20:44 3736149128:11] [[ 7  1]
#      [ 7 23]]
# [D 220420 14:20:44 3736149128:13] Classification Report
# [I 220420 14:20:44 3736149128:16]               precision    recall  f1-score   support
#
#               wt       0.50      0.88      0.64         8
#              mut       0.96      0.77      0.85        30
#
#         accuracy                           0.79        38
#        macro avg       0.73      0.82      0.74        38
#     weighted avg       0.86      0.79      0.81        38
#
# [I 220420 14:20:44 3736149128:20] 0.9583333333333333
# [I 220420 14:20:45 3736149128:46] Saving classification report plots
